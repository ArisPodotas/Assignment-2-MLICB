# %% [markdown]
# <hr>
#
# <center>
#     Class: Machine Learning in Computational Biology <br>
#     Program: Data Science and Information Technologies <br>
#     Name: Aris <br>
#     Las name: Podotas <br>
#     ID: 7115152400040 <br>
#     Assignment: 2 <br>
# </center>
#
# <hr>

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.metrics import fbeta_score
from sklearn.metrics import jaccard_score
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
import sys
sys.path.append('../src/')
from utils import Utils
from classes import RNCV

# %%
data = pd.read_csv('../data/breast_cancer.csv')

object = RNCV(
    f'Baseline', # name
    data,
    f'../models/Baseline/', # path
    [LogisticRegression, # estimators
     GaussianNB,
     LinearDiscriminantAnalysis,
     SVC,
     RandomForestClassifier],
    [balanced_accuracy_score, # metrics
     f1_score,
     hamming_loss,
     fbeta_score,
     jaccard_score,
     matthews_corrcoef,
     precision_score,
     recall_score],
    10, # loops
    3, # innerFolds
    5, # outerFolds
    {},                 # args for evaluations classes
    {},                 # args for evaluations classes
    {},                 # args for evaluations classes
    {'beta': 2},       # args for evaluations classes
    {},
    {},
    {},
    {}
)

holder = object.fit()
# Out:
# 'interpolate' executed in 0.0020 seconds
# Identified missing data
# 'findMissing' executed in 0.0010 seconds
# 'meadianSubstitution' executed in 0.0664 seconds
# 'findDuplicates' executed in 0.0164 seconds
# 'preprocess' executed in 0.0858 seconds
#   0%|                                                                                                                                 | 0/10 [00:00<?, ?it/s]C:\Users\aPodo\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 'fitting' executed in 0.1949 seconds
# 'useFitModels' executed in 0.0085 seconds
# 'applyMetrics' executed in 0.0421 seconds
# Evaluations for i.f 0, o.f 0: [[0.95063352 0.96246713 0.94119053 0.90425532 0.94621085]
#  [0.92783505 0.95652174 0.93333333 0.89411765 0.93478261]
#  [0.05147059 0.02941176 0.04411765 0.06617647 0.04411765]
#  [0.94537815 0.94420601 0.90909091 0.84070796 0.92274678]
#  [0.86538462 0.91666667 0.875      0.80851064 0.87755102]
#  [0.88892105 0.93481968 0.90245262 0.85688953 0.90195964]
#  [0.9        0.97777778 0.97674419 1.         0.95555556]
#  [0.95744681 0.93617021 0.89361702 0.80851064 0.91489362]]
# 'visualiseEvaluations' executed in 1.4135 seconds
# 'fitting' executed in 0.1788 seconds
# 'useFitModels' executed in 0.0071 seconds
# C:\Users\aPodo\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 'applyMetrics' executed in 0.0430 seconds
# Evaluations for i.f 1, o.f 0: [[0.93857272 0.95076784 0.94760614 0.86427281 0.96612466]
#  [0.92592593 0.94339623 0.94230769 0.84210526 0.96226415]
#  [0.05882353 0.04411765 0.04411765 0.11029412 0.02941176]
#  [0.92592593 0.93283582 0.92105263 0.77821012 0.95149254]
#  [0.86206897 0.89285714 0.89090909 0.72727273 0.92727273]
#  [0.87714544 0.90770643 0.90843867 0.77679572 0.9386303 ]
#  [0.92592593 0.96153846 0.98       0.97560976 0.98076923]
#  [0.92592593 0.92592593 0.90740741 0.74074074 0.94444444]]
# 'visualiseEvaluations' executed in 1.3341 seconds
# 'fitting' executed in 0.1744 seconds
# 'useFitModels' executed in 0.0066 seconds
# C:\Users\aPodo\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 'applyMetrics' executed in 0.0435 seconds
# Evaluations for i.f 2, o.f 0: [[0.88920455 0.87310606 0.90056818 0.84280303 0.87878788]
#  [0.86666667 0.84444444 0.88636364 0.80952381 0.85393258]
#  [0.08823529 0.10294118 0.07352941 0.11764706 0.09558824]
#  [0.83333333 0.81196581 0.84051724 0.74561404 0.81545064]
#  [0.76470588 0.73076923 0.79591837 0.68       0.74509804]
#  [0.80515831 0.77185493 0.84023891 0.742652   0.78892241]
#  [0.92857143 0.9047619  0.975      0.94444444 0.92682927]
#  [0.8125     0.79166667 0.8125     0.70833333 0.79166667]]
#   0%|                                                                                                                                 | 0/10 [00:05<?, ?it/s]
# 'visualiseEvaluations' executed in 1.4067 seconds
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 33
#       1 data = pd.read_csv('../data/breast_cancer.csv')
#       3 object = RNCV(
#       4     f'Baseline', # name
#       5     data,
#    (...)
#      30     {}
#      31 )
# ---> 33 holder = object.fit()
#
# File ~\Documents\Assignment-2-MLICB\notebooks\../src\utils.py:15, in timeit.<locals>.wrapper(hush, *args, **kwargs)
#      13 def wrapper(*args, hush: bool = False, **kwargs):
#      14 	start= time()
# ---> 15 	result = func(*args, **kwargs)
#      16 	end = time()
#      17 	elapsed = end - start
#
# File ~\Documents\Assignment-2-MLICB\notebooks\../src\classes.py:123, in RNCV.fit(self, fs, opt, plot)
#     115             # Plot
#     116             self.visualiseEvaluations(
#     117                 self.innerFoldEvaluations[index],
#     118                 self.innerFoldModels[index],
#    (...)
#     121                 name2 = split
#     122             )
# --> 123         self.plotKfold(self.innerFoldModels, self.metrics, self.innerFoldEvaluations)
#     124         # Evaluate
#     125         # Plot
#     126 return None
#
# File ~\Documents\Assignment-2-MLICB\notebooks\../src\utils.py:15, in timeit.<locals>.wrapper(hush, *args, **kwargs)
#      13 def wrapper(*args, hush: bool = False, **kwargs):
#      14 	start= time()
# ---> 15 	result = func(*args, **kwargs)
#      16 	end = time()
#      17 	elapsed = end - start
#
# File ~\Documents\Assignment-2-MLICB\notebooks\../src\classes.py:256, in RNCV.plotKfold(self, methods, metrics, scores)
#     254 for i in range(temp): # Should iterate input col
#     255     for index in range(holder): # Should iterate input row
# --> 256         ax[index, i].boxplot(scores[:, i, index, :], showmeans=True, meanline=True, sym = '.') # index, i is row, col in matplotlib
#     257         ax[index, i].set_title(f"Metric: {metrics[i].__name__}") # Funciton are first class objects in python so __name__ just returns the function name string
#     258         ax[index, i].grid()
#
# TypeError: list indices must be integers or slices, not tuple

# %% [markdown]
# <hr>
#
# <hr>
