# %% [markdown]
# <hr>
#
# <center>
#     Class: Machine Learning in Computational Biology <br>
#     Program: Data Science and Information Technologies <br>
#     Name: Aris <br>
#     Las name: Podotas <br>
#     ID: 7115152400040 <br>
#     Assignment: 2 <br>
# </center>
#
# <hr>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append('../src/')
from utils import Utils

# %%
root = '../data/'
data = pd.read_csv(root + 'breast_cancer.csv')
utils = Utils('../figures/')

# %%
data.describe()
# Out:
#                id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  512.000000    505.00000    507.000000      507.000000   508.000000
# mean   256.500000     14.17355     19.364142       92.231933   657.616929
# std    147.945936      3.55379      4.314426       24.584304   357.110765
# min      1.000000      6.98100      9.710000       43.790000   143.500000
# 25%    128.750000     11.71000     16.195000       75.235000   420.175000
# 50%    256.500000     13.40000     18.890000       86.340000   548.750000
# 75%    384.250000     15.78000     21.830000      104.200000   784.150000
# max    512.000000     28.11000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       506.000000        511.000000      502.000000           504.000000
# mean          0.096168          0.103624        0.088031             0.048893
# ...

# %%
data.describe().to_csv(root + 'statistics.csv')

# %%
data = utils.interpolate(data, 1, [0, 1])

if utils.findMissing(data):
    data = utils.meadianSubstitution(data)

# print(data.isna()) # turn this on if you want you wont find any true values I checked
data.head()
# Out:
# 'interpolate' executed in 0.0022 seconds
# Identified missing data
# 'findMissing' executed in 0.0011 seconds
# 'meadianSubstitution' executed in 0.0663 seconds
#    id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0   1         1        14.68         20.13           94.74      684.5
# 1   2         0        11.50         18.45           73.28      407.4
# 2   3         1        15.85         23.95          103.70      782.7
# 3   4         1        18.82         21.97          123.70     1110.0
# 4   5         0        12.95         16.02           83.14      513.7
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.09867           0.07200         0.07395              0.05259
# 1          0.09345           0.05991         0.02638              0.02069
# 2          0.08401           0.10020         0.09938              0.05364
# 3          0.10180           0.13890         0.15940              0.08744
# ...

# %% [markdown]
# <hr>
#
# So there was missing data
#
# <hr>

# %%
if utils.findDuplicates(data):
    data = utils.copyPrune(data)

data.head(10)
# Out:
# 'findDuplicates' executed in 0.0167 seconds
#    id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0   1         1       14.680         20.13           94.74      684.5
# 1   2         0       11.500         18.45           73.28      407.4
# 2   3         1       15.850         23.95          103.70      782.7
# 3   4         1       18.820         21.97          123.70     1110.0
# 4   5         0       12.950         16.02           83.14      513.7
# 5   6         0       12.470         18.60           81.09      481.9
# 6   7         1       20.480         21.46          132.50     1306.0
# 7   8         0       13.640         16.34           87.21      571.8
# 8   9         0        9.904         18.06           64.60      302.4
# 9  10         0       12.180         14.08           77.25      461.4
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.09867           0.07200         0.07395             0.052590
# ...

# %% [markdown]
# <hr>
#
# It seems there are no duplicate fields.
#
# Let us save our data up till now.
#
# <hr>

# %%
data.to_csv(root + 'filtered.csv')

# %%
data.hist(figsize=(16, 16))
plt.savefig('../figures/Data feature histograms')

# %%
utils.correlation(data)
# Out:
# 'upperTriangle' executed in 0.0000 seconds
# 'correlation' executed in 0.2469 seconds

# %%
utils.twoCol(data, 1)
# Out:
# 'twoCol' executed in 3.4904 seconds

# %%
utils.searchPca(data)
# Out:
# 'searchPca' executed in 0.3112 seconds
